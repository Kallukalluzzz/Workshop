# %% [markdown]
# <a href="https://colab.research.google.com/github/Kallukalluzzz/Workshop/blob/master/Miniproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os
from pandas_profiling import ProfileReport

# %%
data=pd.read_csv("/DGA dataset_new.csv")

# %%
data
# Out:
#       NM       H2      CH4    C2H6    C2H4    C2H2               Type
# 0      1   3930.0   2397.0   157.0     0.0     0.0  Partial discharge
# 1      2  37800.0   1740.0   249.0     8.0     8.0  Partial discharge
# 2      3  92600.0  10200.0     0.0     0.0     0.0  Partial discharge
# 3      4   8266.0   1061.0    22.0     0.0     0.0  Partial discharge
# 4      5   9340.0    995.0    60.0     6.0     7.0  Partial discharge
# ..   ...      ...      ...     ...     ...     ...                ...
# 266  267   2443.0   3422.0  7852.0  3000.0  6394.0           No fault
# 267  268   4395.0   5201.0  6933.0  6788.0  2121.0           No fault
# 268  269   7613.0   1120.0  3363.0  4751.0  3393.0           No fault
# 269  270   2366.0   1031.0  5909.0   108.0  7025.0           No fault
# 270  271   5054.0   4144.0  4174.0  7020.0  6974.0           No fault
#
# [271 rows x 7 columns]

# %%
data.head()
# Out:
#    NM       H2      CH4   C2H6  C2H4  C2H2               Type
# 0   1   3930.0   2397.0  157.0   0.0   0.0  Partial discharge
# 1   2  37800.0   1740.0  249.0   8.0   8.0  Partial discharge
# 2   3  92600.0  10200.0    0.0   0.0   0.0  Partial discharge
# 3   4   8266.0   1061.0   22.0   0.0   0.0  Partial discharge
# 4   5   9340.0    995.0   60.0   6.0   7.0  Partial discharge

# %%
data.tail()
# Out:
#       NM      H2     CH4    C2H6    C2H4    C2H2      Type
# 266  267  2443.0  3422.0  7852.0  3000.0  6394.0  No fault
# 267  268  4395.0  5201.0  6933.0  6788.0  2121.0  No fault
# 268  269  7613.0  1120.0  3363.0  4751.0  3393.0  No fault
# 269  270  2366.0  1031.0  5909.0   108.0  7025.0  No fault
# 270  271  5054.0  4144.0  4174.0  7020.0  6974.0  No fault

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NM      271 non-null    int64
#  1   H2      271 non-null    float64
#  2   CH4     271 non-null    float64
#  3   C2H6    271 non-null    float64
#  4   C2H4    271 non-null    float64
#  5   C2H2    271 non-null    float64
#  6   Type    271 non-null    object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 14.9+ KB

# %%
data.describe()
# Out:
#                NM             H2            CH4           C2H6           C2H4  \
# count  271.000000     271.000000     271.000000     271.000000     271.000000
# mean   136.000000   12596.872137    8837.367860    8322.011037   25855.278192
# std     78.375166   58990.313685   44290.029786   45204.575453   93324.626287
# min      1.000000       0.000000       0.000000       0.000000       0.000000
# 25%     68.500000      87.585000      59.950000      10.000000      15.050000
# 50%    136.000000     676.740000     450.000000      68.000000     233.000000
# 75%    203.500000    4105.000000    1593.000000     510.000000    2030.000000
# max    271.000000  487297.000000  449556.000000  404053.000000  478904.000000
#
#                 C2H2
# count     271.000000
# mean    28464.202989
# std    118859.936760
# min         0.000000
# 25%         3.110000
# 50%        40.000000
# 75%       890.850000
# max    683643.000000

# %%
data.isnull()
# Out:
#         NM     H2    CH4   C2H6   C2H4   C2H2   Type
# 0    False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...
# 266  False  False  False  False  False  False  False
# 267  False  False  False  False  False  False  False
# 268  False  False  False  False  False  False  False
# 269  False  False  False  False  False  False  False
# 270  False  False  False  False  False  False  False
#
# [271 rows x 7 columns]

# %%
plt.figure(figsize=(15,7))
plt.style.use("fivethirtyeight")
sns.kdeplot(data=data, x="H2")

# %%
plt.figure(figsize=(15,7))
plt.style.use("fivethirtyeight")
sns.kdeplot(data=data, x="CH4")

# %%
plt.figure(figsize=(15,7))
plt.style.use("fivethirtyeight")
sns.kdeplot(data=data, x="C2H6")

# %%
plt.figure(figsize=(15,7))
plt.style.use("fivethirtyeight")
sns.kdeplot(data=data, x="C2H4")

# %%
plt.figure(figsize=(15,7))
plt.style.use("fivethirtyeight")
sns.kdeplot(data=data, x="C2H2")

# %%
sns.pairplot(data=data)

# %%
plt.figure(figsize=(20,10))
c=data.corr()
sns.heatmap(c,cmap='BrBG',annot=True)

# %%
data.isnull().any()
# Out:
# NM      False
# H2      False
# CH4     False
# C2H6    False
# C2H4    False
# C2H2    False
# Type    False
# dtype: bool

# %%
result_df=pd.DataFrame({
    
    'H2(ppm)':[],
    'CH4(ppm)':[],
    'C2H6(ppm)':[],
    'C2H4(ppm)':[],
    'C2H2(ppm)':[],
    'Condition':[],
    'Fault':[] 
})

# %%
        CH4=float(data[(data.name=='Methane - CH4')].reported_value)
        H2=float(data[(data.name=='Hydrogen - H2')].reported_value)
        C2H2=float(data[(data.name=='Acetylene- C2H2')].reported_value)
        C2H4=float(data[(data.name=='Ethylene - C2H4')].reported_value)
        C2H6=float(data[(data.name=='Ethane - C2H6')].reported_value)
        if((H2<=100) and (CH4<=120) and (C2H2<=1) and (C2H4<=50) and (C2H6<=65)):
            condition='Condition 1'
        else:
            if(((H2>=101) and (H2<=700)) or ((CH4>=121) and (CH4<=400)) or ((C2H2>=2) and (C2H2<=9)) or 
               ((C2H4>=51) and (C2H4<=100)) or ((C2H6>=66) and (C2H6<=100))):
                condition='Condition 2'
                execute=False
            if(((H2>=701) and (H2<1800)) or ((CH4>=401) and (CH4<1000)) or ((C2H2>=10) and (C2H2<35)) or 
               ((C2H4>=101) and (C2H4<200)) or ((C2H6>=101) and (C2H6<150))):
                condition='Condition 3'
                execute=False
            elif((H2>= 1800) or (CH4>=1000) or (C2H2>=35) or (C2H4>=200) or (C2H6>=150)):
                condition='Condition 4'
                execute=False
        if(H2>=1000):
            fault.append(('Corona,Arching'))
        elif(CH4>=80):
            fault.append(('Sparking'))
        elif(C2H2>=70):
            fault.append(('Arching'))
        elif(C2H4>=150):
            fault.append(('Severe Overheating'))
        elif(C2H6>=35):
            fault.append(('Local Overheating'))
        elif((condition!='Condition 1') and (condition!='Condition 4')):
            fault.append('Need Resampling')
        elif(execute):
            fault.append(('No fault'))
        temp_df=pd.DataFrame({
            
            'H2(ppm)':[],
            'CH4(ppm)':[],
            'C2H6(ppm)':[],
            'C2H4(ppm)':[],
            'C2H2(ppm)':[],
            'Condition':[],
            'Fault':[] 
        })
        result_df=result_df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-29d0c8d83938> in <module>()
# ----> 1 CH4=float(data[(data.name=='Methane - CH4')].reported_value)
#       2 H2=float(data[(data.name=='Hydrogen - H2')].reported_value)
#       3 C2H2=float(data[(data.name=='Acetylene- C2H2')].reported_value)
#       4 C2H4=float(data[(data.name=='Ethylene - C2H4')].reported_value)
#       5 C2H6=float(data[(data.name=='Ethane - C2H6')].reported_value)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'name'
